# %% [markdown]
# # Fortnite to Pubg

# %%
import os
import cv2
import numpy as np
from datetime import datetime

from __future__ import print_function, division
import scipy
from keras_contrib.layers.normalization import InstanceNormalization
from keras.layers import Input, Dense, Reshape, Flatten, Dropout, Concatenate, BatchNormalization, Activation, MaxPooling2D
from keras.layers.advanced_activations import LeakyReLU
from keras.layers.convolutional import UpSampling2D, Conv2D
from keras.models import Sequential, Model, model_from_json
from keras.optimizers import Adam
import sys

# %%
CHECKPOINT = "checkpoint/"

EPOCHS = 100
BATCH_SIZE = 1
TIME_INTERVALS = 5 # Saves Model in every N minutes

SHOW_SUMMARY = True

DISCRIMINATOR_LR_RATE = 0.0002
GENERATOR_LR_RATE = 0.0004

# %%
IMAGE_ROWS = 256
IMAGE_COLS = 256
IMAGE_CHANNELS = 3
IMAGE_SHAPE = (IMAGE_ROWS, IMAGE_COLS, IMAGE_CHANNELS)

# %% [markdown]
# ## Load Data

# %%
from dataloader import Data
data = Data()

# %% [markdown]
# ## Build Models

# %%
# Calculate output shape of D (PatchGAN)
patch = int(IMAGE_ROWS / 2**4)
patch = (patch, patch, 1)

# %% [markdown]
# ### Build Discriminator
# #### We are going to build [PatchGAN](https://image.slidesharecdn.com/07-image-to-imagetranslationwithconditionaladversarialnetworks-161125155412/95/imagetoimage-translation-with-conditional-adversarial-nets-upc-reading-group-24-638.jpg?cb=1480089468) Discriminator

# %%
d_layers = 4 # discriminator size
d_filter_size = 64 # filter size of first layer
d_loss = 'mse' # mean squared error
d_optimizer = Adam(DISCRIMINATOR_LR_RATE, 0.5)

# %%
def build_d_layer(layer_input, filters, f_size=3, normalization=True):
    d = Conv2D(filters, kernel_size=f_size, strides=1, padding='same')(layer_input)
    d = MaxPooling2D(pool_size=(2, 2), strides=None, padding='valid', data_format=None)(d)
    d = LeakyReLU(alpha=0.2)(d)
    if normalization:
        d = InstanceNormalization()(d)
    return d
    
    
def build_discriminator():
    image = Input(shape=IMAGE_SHAPE)
    layers  = []
    
    # Making  N (d_layers) Layers 
    for i in range(d_layers):
        filter_size = d_filter_size * (2 ** i)
        if not i:
            layer = build_d_layer(image, filter_size, normalization=False)
        else:
            layer = build_d_layer(layers[-1], filter_size)
            
        layers.append(layer)
    
    confidence = Conv2D(1, kernel_size=4, strides=1, padding='same')(layers[-1])
    
    # Model(input, output)
    return Model(image, confidence)

# %%
# Discriminator Initialization
DCRM_A = build_discriminator()
DCRM_B = build_discriminator()

# Compile the Discriminator Model
DCRM_A.compile(loss=d_loss, optimizer=d_optimizer, metrics=['accuracy'])
DCRM_B.compile(loss=d_loss, optimizer=d_optimizer, metrics=['accuracy'])

# Discriminator Model shouldn't be affected during Adverserial(Combined Model) Optimization
DCRM_A.trainable = False
DCRM_B.trainable = False

# Show Summary
if SHOW_SUMMARY:
    print('DCRM_A')
    DCRM_A.summary()
    print('DCRM_B')
    DCRM_B.summary()
# Out:
# DCRM_A
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 256, 256, 3)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 256, 256, 64)      1792
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 128, 128, 64)      0
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 128, 128, 64)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 128, 128, 128)     73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 64, 64, 128)       0
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 64, 64, 128)       0
# _________________________________________________________________
# instance_normalization_1 (In (None, 64, 64, 128)       2
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 64, 64, 256)       295168
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 32, 32, 256)       0
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# instance_normalization_2 (In (None, 32, 32, 256)       2
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 32, 32, 512)       1180160
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 16, 16, 512)       0
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 16, 16, 512)       0
# _________________________________________________________________
# instance_normalization_3 (In (None, 16, 16, 512)       2
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 16, 16, 1)         8193
# =================================================================
# Total params: 3,118,350
# Trainable params: 1,559,175
# Non-trainable params: 1,559,175
# _________________________________________________________________
# DCRM_B
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 256, 256, 3)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 256, 256, 64)      1792
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 128, 128, 64)      0
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 128, 128, 64)      0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 128, 128, 128)     73856
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 64, 64, 128)       0
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 64, 64, 128)       0
# _________________________________________________________________
# instance_normalization_4 (In (None, 64, 64, 128)       2
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 64, 64, 256)       295168
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 32, 32, 256)       0
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# instance_normalization_5 (In (None, 32, 32, 256)       2
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 32, 32, 512)       1180160
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 16, 16, 512)       0
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 16, 16, 512)       0
# _________________________________________________________________
# instance_normalization_6 (In (None, 16, 16, 512)       2
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 16, 16, 1)         8193
# =================================================================
# Total params: 3,118,350
# Trainable params: 1,559,175
# Non-trainable params: 1,559,175
# _________________________________________________________________
# /usr/local/lib/python3.5/dist-packages/keras/engine/training.py:478: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'

# %% [markdown]
# ### Build Generator
# #### We are going to build a [U-Net ](https://cdn-images-1.medium.com/max/953/1*Z98NhzbVISHa4CoemZS4Kw.png) Generator

# %%
g_filter_size = 64 # filter size of first layer
dropout = 0.25
g_optimizer = Adam(GENERATOR_LR_RATE, 0.5)

# %%
def build_conv2d(layer_input, filters, stride=1, f_size=3):
    g = Conv2D(filters, kernel_size=f_size, strides=stride, padding='same')(layer_input)
    g = MaxPooling2D(pool_size=(2, 2), strides=None, padding='valid', data_format=None)(g)
    g = LeakyReLU(alpha=0.2)(g)
    g = InstanceNormalization()(g)
    return g


def build_deconv2d(layer_input, skip_input, filters, f_size=3, dropout_rate=0):
    g = UpSampling2D(size=2)(layer_input)
    g = Conv2D(filters, kernel_size=f_size, strides=1, padding='same', activation='relu')(g)
    if dropout_rate:
        g = Dropout(dropout_rate)(g)
    g = InstanceNormalization()(g)
    g = Concatenate()([g, skip_input])
    return g


def build_generator():
    image = Input(shape=IMAGE_SHAPE)
    layers = []
    
    #  DownSampling the layers
    conv1 = build_conv2d(image, g_filter_size)
    conv2 = build_conv2d(conv1, g_filter_size*2)
    conv3 = build_conv2d(conv2, g_filter_size*4)
    conv4 = build_conv2d(conv3, g_filter_size*8)
    conv5 = build_conv2d(conv4, g_filter_size*8)
    
    # UpSampling the Layers
    deconv1 = build_deconv2d(conv5, conv4, g_filter_size*4)
    deconv2 = build_deconv2d(deconv1, conv3, g_filter_size*4)
    deconv3 = build_deconv2d(deconv2, conv2, g_filter_size*2)
    deconv4 = build_deconv2d(deconv3, conv1, g_filter_size)
    deconv5 = UpSampling2D(size=2)(deconv4)
    
    generated_image = Conv2D(IMAGE_CHANNELS, kernel_size=3, strides=1, padding='same', activation='tanh')(deconv5)
    
    return Model(image, generated_image)

# %%
# Generator Initialization
GEN_AB = build_generator()
GEN_BA = build_generator()

IMG_A = Input(shape=IMAGE_SHAPE)
IMG_B = Input(shape=IMAGE_SHAPE)

# Generator Summary
if SHOW_SUMMARY:
    print('GEN_AB')
    GEN_AB.summary()
    print('GEN_BA')
    GEN_BA.summary()
# Out:
# GEN_AB
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 256, 256, 64) 1792        input_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_24 (MaxPooling2D) (None, 128, 128, 64) 0           conv2d_34[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 128, 128, 64) 0           max_pooling2d_24[0][0]
# __________________________________________________________________________________________________
# instance_normalization_27 (Inst (None, 128, 128, 64) 2           leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 128, 128, 128 73856       instance_normalization_27[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_25 (MaxPooling2D) (None, 64, 64, 128)  0           conv2d_35[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 64, 64, 128)  0           max_pooling2d_25[0][0]
# __________________________________________________________________________________________________
# instance_normalization_28 (Inst (None, 64, 64, 128)  2           leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 64, 64, 256)  295168      instance_normalization_28[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_26 (MaxPooling2D) (None, 32, 32, 256)  0           conv2d_36[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 32, 32, 256)  0           max_pooling2d_26[0][0]
# __________________________________________________________________________________________________
# instance_normalization_29 (Inst (None, 32, 32, 256)  2           leaky_re_lu_26[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 32, 32, 512)  1180160     instance_normalization_29[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_27 (MaxPooling2D) (None, 16, 16, 512)  0           conv2d_37[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, 16, 16, 512)  0           max_pooling2d_27[0][0]
# __________________________________________________________________________________________________
# instance_normalization_30 (Inst (None, 16, 16, 512)  2           leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 16, 16, 512)  2359808     instance_normalization_30[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_28 (MaxPooling2D) (None, 8, 8, 512)    0           conv2d_38[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_28 (LeakyReLU)      (None, 8, 8, 512)    0           max_pooling2d_28[0][0]
# __________________________________________________________________________________________________
# instance_normalization_31 (Inst (None, 8, 8, 512)    2           leaky_re_lu_28[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_8 (UpSampling2D)  (None, 16, 16, 512)  0           instance_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 16, 16, 256)  1179904     up_sampling2d_8[0][0]
# __________________________________________________________________________________________________
# instance_normalization_32 (Inst (None, 16, 16, 256)  2           conv2d_39[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 16, 16, 768)  0           instance_normalization_32[0][0]
#                                                                  instance_normalization_30[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_9 (UpSampling2D)  (None, 32, 32, 768)  0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 32, 32, 256)  1769728     up_sampling2d_9[0][0]
# __________________________________________________________________________________________________
# instance_normalization_33 (Inst (None, 32, 32, 256)  2           conv2d_40[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 32, 32, 512)  0           instance_normalization_33[0][0]
#                                                                  instance_normalization_29[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_10 (UpSampling2D) (None, 64, 64, 512)  0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 64, 64, 128)  589952      up_sampling2d_10[0][0]
# __________________________________________________________________________________________________
# instance_normalization_34 (Inst (None, 64, 64, 128)  2           conv2d_41[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 64, 64, 256)  0           instance_normalization_34[0][0]
#                                                                  instance_normalization_28[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_11 (UpSampling2D) (None, 128, 128, 256 0           concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 128, 128, 64) 147520      up_sampling2d_11[0][0]
# __________________________________________________________________________________________________
# instance_normalization_35 (Inst (None, 128, 128, 64) 2           conv2d_42[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 128, 128, 128 0           instance_normalization_35[0][0]
#                                                                  instance_normalization_27[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_12 (UpSampling2D) (None, 256, 256, 128 0           concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 256, 256, 3)  3459        up_sampling2d_12[0][0]
# ==================================================================================================
# Total params: 7,601,365
# Trainable params: 7,601,365
# Non-trainable params: 0
# __________________________________________________________________________________________________
# GEN_BA
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_8 (InputLayer)            (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 256, 256, 64) 1792        input_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_29 (MaxPooling2D) (None, 128, 128, 64) 0           conv2d_44[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)      (None, 128, 128, 64) 0           max_pooling2d_29[0][0]
# __________________________________________________________________________________________________
# instance_normalization_36 (Inst (None, 128, 128, 64) 2           leaky_re_lu_29[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 128, 128, 128 73856       instance_normalization_36[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_30 (MaxPooling2D) (None, 64, 64, 128)  0           conv2d_45[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_30 (LeakyReLU)      (None, 64, 64, 128)  0           max_pooling2d_30[0][0]
# __________________________________________________________________________________________________
# instance_normalization_37 (Inst (None, 64, 64, 128)  2           leaky_re_lu_30[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 64, 64, 256)  295168      instance_normalization_37[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_31 (MaxPooling2D) (None, 32, 32, 256)  0           conv2d_46[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_31 (LeakyReLU)      (None, 32, 32, 256)  0           max_pooling2d_31[0][0]
# __________________________________________________________________________________________________
# instance_normalization_38 (Inst (None, 32, 32, 256)  2           leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 32, 32, 512)  1180160     instance_normalization_38[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_32 (MaxPooling2D) (None, 16, 16, 512)  0           conv2d_47[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, 16, 16, 512)  0           max_pooling2d_32[0][0]
# __________________________________________________________________________________________________
# instance_normalization_39 (Inst (None, 16, 16, 512)  2           leaky_re_lu_32[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 16, 16, 512)  2359808     instance_normalization_39[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_33 (MaxPooling2D) (None, 8, 8, 512)    0           conv2d_48[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, 8, 8, 512)    0           max_pooling2d_33[0][0]
# __________________________________________________________________________________________________
# instance_normalization_40 (Inst (None, 8, 8, 512)    2           leaky_re_lu_33[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_13 (UpSampling2D) (None, 16, 16, 512)  0           instance_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 16, 16, 256)  1179904     up_sampling2d_13[0][0]
# __________________________________________________________________________________________________
# instance_normalization_41 (Inst (None, 16, 16, 256)  2           conv2d_49[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 16, 16, 768)  0           instance_normalization_41[0][0]
#                                                                  instance_normalization_39[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_14 (UpSampling2D) (None, 32, 32, 768)  0           concatenate_10[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 32, 32, 256)  1769728     up_sampling2d_14[0][0]
# __________________________________________________________________________________________________
# instance_normalization_42 (Inst (None, 32, 32, 256)  2           conv2d_50[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 32, 32, 512)  0           instance_normalization_42[0][0]
#                                                                  instance_normalization_38[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_15 (UpSampling2D) (None, 64, 64, 512)  0           concatenate_11[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 64, 64, 128)  589952      up_sampling2d_15[0][0]
# __________________________________________________________________________________________________
# instance_normalization_43 (Inst (None, 64, 64, 128)  2           conv2d_51[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 64, 64, 256)  0           instance_normalization_43[0][0]
#                                                                  instance_normalization_37[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_16 (UpSampling2D) (None, 128, 128, 256 0           concatenate_12[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 128, 128, 64) 147520      up_sampling2d_16[0][0]
# __________________________________________________________________________________________________
# instance_normalization_44 (Inst (None, 128, 128, 64) 2           conv2d_52[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 128, 128, 128 0           instance_normalization_44[0][0]
#                                                                  instance_normalization_36[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_17 (UpSampling2D) (None, 256, 256, 128 0           concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 256, 256, 3)  3459        up_sampling2d_17[0][0]
# ==================================================================================================
# Total params: 7,601,365
# Trainable params: 7,601,365
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### Adverserial Net (Combined Network) CYCLE

# %%
# Prepare fake images from Generator
FAKE_IMG_A = GEN_BA(IMG_B)
FAKE_IMG_B = GEN_AB(IMG_A)

# Reconstruct fake images back to original
RECONSTRUCT_A = GEN_BA(FAKE_IMG_A)
RECONSTRUCT_B = GEN_AB(FAKE_IMG_B)

# Original Idendity of the Image
ID_A = GEN_BA(IMG_A)
ID_B = GEN_AB(IMG_B)

# Discriminator Confidence of Fake images
CONF_FAKE_IMG_A = DCRM_A(FAKE_IMG_A)
CONF_FAKE_IMG_B = DCRM_B(FAKE_IMG_B)

# %% [markdown]
# #### Initialize Adverserial Net - Combined Network - Cycle

# %%
COMBINED = Model([IMG_A, IMG_B],
                [CONF_FAKE_IMG_A, CONF_FAKE_IMG_B,
                 RECONSTRUCT_A, RECONSTRUCT_B,
                 ID_A, ID_B])

COMBINED.compile(loss= ['mse', 'mse',
                        'mae', 'mae',
                        'mae', 'mae'], 
                 loss_weights = [1, 1,
                                 0.1, 0.1,
                                 1, 1],
                 optimizer = g_optimizer)

# Combined Summary
if SHOW_SUMMARY:
    print('Combined Model')
    COMBINED.summary()
# Out:
# Combined Model
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_10 (InputLayer)           (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# input_9 (InputLayer)            (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# model_4 (Model)                 (None, 256, 256, 3)  7601365     input_10[0][0]
#                                                                  model_4[4][0]
#                                                                  input_9[0][0]
# __________________________________________________________________________________________________
# model_3 (Model)                 (None, 256, 256, 3)  7601365     input_9[0][0]
#                                                                  model_3[4][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# model_1 (Model)                 (None, 16, 16, 1)    1559175     model_4[4][0]
# __________________________________________________________________________________________________
# model_2 (Model)                 (None, 16, 16, 1)    1559175     model_3[4][0]
# ==================================================================================================
# Total params: 18,321,080
# Trainable params: 15,202,730
# Non-trainable params: 3,118,350
# __________________________________________________________________________________________________

# %% [markdown]
# ## Utilities

# %%
def save_model():
    pass

def load_model():
    return 0

def save_log():
    pass

def display(img1_real, img1_fake, img2_real, img2_fake):
    pass

# %% [markdown]
# ## Train Model

# %%
def train():
    start_time = datetime.datetime.now()
    saved_time = start_time
    last_epoch = load_model()
    
    for epoch in EPOCHS:
        steps = 1
        while True:
            imgA, imgB = data.get_data(BATCH_SIZE)
            
            # If value is None it means it is out of data,
            # it auto resets the data loader and breaks out of 'while' loop as next batch
            if imgA is None or imgB is None:
                break
            
            batch_size = imgA.shape[0]
            
            # Rescale the image value from 255 => -1 to 1
            imgs_A = imgs_A / 127.5 - 1
            imgs_B = imgs_B / 127.5 - 1
            
            # Discriminator Ground Truth
            real = np.ones((batch_size,) + patch)
            fake = np.zeros((batch_size,) + patch)
            
            # Train Discriminator
            fake_A = GEN_BA(imgs_B)
            fake_b = GEN_AB(imgs_A)
            
            dA_loss_real = DCRM_A.train_on_batch(imgs_A, real)
            dA_loss_fake = DCRM_A.train_on_batch(fake_A, fake)
            dA_loss = 0.5 * np.add(dA_loss_real, dA_loss_fake)
            
            dB_loss_real = DCRM_A.train_on_batch(imgs_B, real)
            dB_loss_fake = DCRM_A.train_on_batch(fake_B, fake)
            dB_loss = 0.5 * np.add(dB_loss_real, dB_loss_fake)
            
            d_loss = 0.5 * np.add(dA_loss, dB_loss)
            
            
            # Train Generator
            g_loss = COMBINED.train_on_batch([imgs_A, imgs_B],
                                             [real, real,
                                              imgs_A, imgs_B,
                                              imgs_A, imgs_B])
            
            # Save Model
            current_time = datetime.datetime.now()
            difference_time = current_time - saved_time
            if difference_time.seconds >= (TIME_INTERVALS * 60):
                save_model()
            display(imgs_A, fake_A, imgs_B, fake_b)
            
            # Print and Save Log
            log = "Ep: %d, steps: %d, [D loss: %f, acc: %3d%%], [G loss: %f]" %(epoch+last_epoch,
                                                                                steps, d_loss[0], 100*d_loss[1],
                                                                                g_loss[0])
            print(log)
            save_log(log)
            steps += 1

# %%
train()
